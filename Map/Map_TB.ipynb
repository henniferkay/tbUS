# %%
import pandas as pd
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Specify the path to your CSV file
csv_file_path = 'resources/merged_cases.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame to verify
df.head()
# Out:
#    Year   Geography  American Indian/Alaska Native  Asian  \
# 0  2000     Alabama                              1      7
# 1  2000      Alaska                             71     15
# 2  2000     Arizona                             29     28
# 3  2000    Arkansas                              1     10
# 4  2000  California                             15   1333
#
#    Black/African American  Hispanic/Latino  Multiracial  \
# 0                     177               12            0
# 1                       9                2            0
# 2                      21              140            0
# 3                      71               20            0
# 4                     318             1201            0
#
#    Native Hawaiian/Other Pacific Islander  Unknown  White  ...  Non-U.S.–born  \
# 0                                       0        0    113  ...             22
# 1                                       2        0      9  ...             15
# 2                                       1        0     42  ...            148
# 3                                       6        4     87  ...             31
# 4                                      20       17    384  ...           2369
#
#    U.S.-born  0-4  15-24  25-34  35-44  45-54  14-May  55-64  65+
# 0        288    8     16     29     62     51       8     38   98
# 1         93   18     13      8     26      8      11     12   12
# 2        112   12     33     43     48     43       6     22   54
# 3        165    9     20     17     24     24      16     20   69
# 4        904  115    327    537    520    505      89    433  762
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Geography', 'American Indian/Alaska Native', 'Asian',
#        'Black/African American', 'Hispanic/Latino', 'Multiracial',
#        'Native Hawaiian/Other Pacific Islander', 'Unknown', 'White', 'Female',
#        'Male', 'Non-U.S.–born', 'U.S.-born', '0-4', '15-24', '25-34', '35-44',
#        '45-54', '14-May', '55-64', '65+'],
#       dtype='object')

# %%
# Combine 'Male' and 'Female' columns to create a new Series representing the sum
df['Combined'] = df['Male'] + df['Female']

# Display the updated DataFrame with the new 'Combined' column
df
# Out:
#       Year      Geography  American Indian/Alaska Native  Asian  \
# 0     2000        Alabama                              1      7
# 1     2000         Alaska                             71     15
# 2     2000        Arizona                             29     28
# 3     2000       Arkansas                              1     10
# 4     2000     California                             15   1333
# ...    ...            ...                            ...    ...
# 1168  2022       Virginia                              0     95
# 1169  2022     Washington                              4     95
# 1170  2022  West Virginia                              0      3
# 1171  2022      Wisconsin                              0     22
# 1172  2022        Wyoming                              1      0
#
#       Black/African American  Hispanic/Latino  Multiracial  \
# 0                        177               12            0
# 1                          9                2            0
# 2                         21              140            0
# 3                         71               20            0
# 4                        318             1201            0
# ...                      ...              ...          ...
# 1168                      32               40            6
# 1169                      46               48            4
# 1170                       2                1            0
# 1171                       8               15            0
# 1172                       0                0            0
#
#       Native Hawaiian/Other Pacific Islander  Unknown  White  ...  U.S.-born  \
# 0                                          0        0    113  ...        288
# 1                                          2        0      9  ...         93
# 2                                          1        0     42  ...        112
# 3                                          6        4     87  ...        165
# 4                                         20       17    384  ...        904
# ...                                      ...      ...    ...  ...        ...
# 1168                                       0        0     22  ...         26
# 1169                                      38        1     15  ...         67
# 1170                                       0        0      5  ...          6
# 1171                                       0        0      7  ...         12
# 1172                                       0        0      0  ...          1
#
#       0-4  15-24  25-34  35-44  45-54  14-May  55-64  65+  Combined
# 0       8     16     29     62     51       8     38   98       310
# 1      18     13      8     26      8      11     12   12       108
# 2      12     33     43     48     43       6     22   54       261
# 3       9     20     17     24     24      16     20   69       199
# 4     115    327    537    520    505      89    433  762      3288
# ...   ...    ...    ...    ...    ...     ...    ...  ...       ...
# 1168    3     17     32     21     26       2     28   66       195
# 1169    9     32     41     46     34       7     32   50       251
# 1170    0      0      2      3      1       0      3    2        11
# 1171    1      5      8      6     11       0      7   14        52
# 1172    0      0      0      0      0       0      1    0         1
#
# [1173 rows x 23 columns]

# %%
plt.figure(figsize=(18, 6))  # Adjust the figure size if needed

plt.bar(df['Year'], df['Combined'])

# Step 5: Customizing the Plot
plt.xlabel('Year')  # Set the label for the x-axis
plt.ylabel('Values')  # Set the label for the y-axis
plt.title('Cases Over Time')  # Set the title of the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed

# Display the plot
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
df.to_csv('complete.csv')
